# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')

cast = df['director']
print(cast)
# Out:
# 0       Jorge Michel Grau
# 1            Gilbert Chan
# 2             Shane Acker
# 3          Robert Luketic
# 4             Serdar Akar
#               ...
# 4807      Ruben Fleischer
# 4808         Shlok Sharma
# 4809         Peter Hewitt
# 4810          Josef Fares
# 4811          Mozez Singh
# Name: director, Length: 4812, dtype: object
