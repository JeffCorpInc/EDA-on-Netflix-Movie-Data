# %%
import pandas as pd
df = pd.read_csv('netflix_data.csv')

dir = df['director']
print(dir)
# Out:
# 0       Jorge Michel Grau
# 1            Gilbert Chan
# 2             Shane Acker
# 3          Robert Luketic
# 4             Serdar Akar
#               ...
# 4807      Ruben Fleischer
# 4808         Shlok Sharma
# 4809         Peter Hewitt
# 4810          Josef Fares
# 4811          Mozez Singh
# Name: director, Length: 4812, dtype: object

# %%
cast = df['cast']
print(cast)
# Out:
# 0       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 1       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 2       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 3       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 4       Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...
#                               ...
# 4807    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 4808    Shashank Arora, Shweta Tripathi, Rahul Kumar, ...
# 4809    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 4810    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 4811    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 4812, dtype: object
